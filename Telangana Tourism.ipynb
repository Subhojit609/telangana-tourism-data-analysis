# %% [markdown]
# # Importing Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Importing Dataset

# %%
domestic_16= pd.read_csv(r"D:\Data Study materials\C5 Input for participants\C5 Input for participants\domestic_visitors\domestic_visitors_2016.csv")
domestic_17= pd.read_csv(r"D:\Data Study materials\C5 Input for participants\C5 Input for participants\domestic_visitors\domestic_visitors_2017.csv")
domestic_18= pd.read_csv(r"D:\Data Study materials\C5 Input for participants\C5 Input for participants\domestic_visitors\domestic_visitors_2018.csv")
domestic_19= pd.read_csv(r"D:\Data Study materials\C5 Input for participants\C5 Input for participants\domestic_visitors\domestic_visitors_2019.csv")

foreign_16= pd.read_csv(r"D:\Data Study materials\C5 Input for participants\C5 Input for participants\foreign_visitors\foreign_visitors_2016.csv")
foreign_17= pd.read_csv(r"D:\Data Study materials\C5 Input for participants\C5 Input for participants\foreign_visitors\foreign_visitors_2017.csv")
foreign_18= pd.read_csv(r"D:\Data Study materials\C5 Input for participants\C5 Input for participants\foreign_visitors\foreign_visitors_2018.csv")
foreign_19= pd.read_csv(r"D:\Data Study materials\C5 Input for participants\C5 Input for participants\foreign_visitors\foreign_visitors_2019.csv")

domestic_16
# Out:
#             district        date      month  year visitors
# 0           Adilabad  01-01-2016    January  2016   792136
# 1           Adilabad  01-02-2016   February  2016   937820
# 2           Adilabad  01-03-2016      March  2016   582946
# 3           Adilabad  01-04-2016      April  2016   341948
# 4           Adilabad  01-05-2016        May  2016   252887
# ..               ...         ...        ...   ...      ...
# 367  Yadadri Bhongir  01-08-2016     August  2016
# 368  Yadadri Bhongir  01-09-2016  September  2016
# 369  Yadadri Bhongir  01-10-2016    October  2016   584800
# 370  Yadadri Bhongir  01-11-2016   November  2016   681000
# 371  Yadadri Bhongir  01-12-2016   December  2016   462800
#
# [372 rows x 5 columns]

# %%
domestic_visitors=pd.concat([domestic_16, domestic_17, domestic_18, domestic_19])
domestic_visitors
# Out:
#             district        date      month  year visitors
# 0           Adilabad  01-01-2016    January  2016   792136
# 1           Adilabad  01-02-2016   February  2016   937820
# 2           Adilabad  01-03-2016      March  2016   582946
# 3           Adilabad  01-04-2016      April  2016   341948
# 4           Adilabad  01-05-2016        May  2016   252887
# ..               ...         ...        ...   ...      ...
# 391  Yadadri Bhongir  01-08-2019     August  2019   389010
# 392  Yadadri Bhongir  01-09-2019  September  2019   366862
# 393  Yadadri Bhongir  01-10-2019    October  2019   381860
# 394  Yadadri Bhongir  01-11-2019   November  2019   365990
# 395  Yadadri Bhongir  01-12-2019   December  2019   477635
#
# [1512 rows x 5 columns]

# %%
foreign_visitors=pd.concat([foreign_16, foreign_17, foreign_18, foreign_19])
foreign_visitors
# Out:
#             district        date      month  year visitors
# 0           Adilabad  01-01-2016    January  2016        2
# 1           Adilabad  01-02-2016   February  2016        0
# 2           Adilabad  01-03-2016      March  2016        2
# 3           Adilabad  01-04-2016      April  2016        0
# 4           Adilabad  01-05-2016        May  2016        0
# ..               ...         ...        ...   ...      ...
# 391  Yadadri Bhongir  01-08-2019     August  2019        0
# 392  Yadadri Bhongir  01-09-2019  September  2019        0
# 393  Yadadri Bhongir  01-10-2019    October  2019        0
# 394  Yadadri Bhongir  01-11-2019   November  2019        0
# 395  Yadadri Bhongir  01-12-2019   December  2019        0
#
# [1512 rows x 5 columns]

# %%
domestic_visitors.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1512 entries, 0 to 395
# Data columns (total 5 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   district  1512 non-null   object
#  1   date      1512 non-null   object
#  2   month     1512 non-null   object
#  3   year      1512 non-null   int64
#  4   visitors  1482 non-null   object
# dtypes: int64(1), object(4)
# memory usage: 70.9+ KB

# %%
domestic_visitors.isnull().sum()
# Out:
# district     0
# date         0
# month        0
# year         0
# visitors    30
# dtype: int64

# %%
foreign_visitors.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1512 entries, 0 to 395
# Data columns (total 5 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   district  1512 non-null   object
#  1   date      1512 non-null   object
#  2   month     1512 non-null   object
#  3   year      1512 non-null   int64
#  4   visitors  1512 non-null   object
# dtypes: int64(1), object(4)
# memory usage: 70.9+ KB

# %%
foreign_visitors.isnull().sum()
# Out:
# district    0
# date        0
# month       0
# year        0
# visitors    0
# dtype: int64

# %%
domestic_visitors['visitors'].value_counts()
# Out:
#           315
# 0          19
# 41         10
# 80500       6
# 300000      4
#          ...
# 1787        1
# 1345        1
# 1378        1
# 965         1
# 477635      1
# Name: visitors, Length: 1027, dtype: int64

# %%
foreign_visitors['visitors'].value_counts()
# Out:
# 0      899
#        320
# 2       10
# 40      10
# 35       9
#       ...
# 57       1
# 56       1
# 123      1
# 126      1
# 210      1
# Name: visitors, Length: 151, dtype: int64

# %% [markdown]
# # Preprocessing

# %%
domestic_visitors['visitors'].fillna("Unknown", inplace=True)
foreign_visitors['visitors'].fillna("Unknown", inplace=True)

# %%
# Replace non-numeric values with NaN
domestic_visitors['visitors'] = pd.to_numeric(domestic_visitors['visitors'], errors='coerce')
foreign_visitors['visitors'] = pd.to_numeric(foreign_visitors['visitors'], errors='coerce')

# Convert 'visitors' column to integers, treating NaN values as 0
domestic_visitors['visitors'] = domestic_visitors['visitors'].fillna(0).astype(int)
foreign_visitors['visitors'] = foreign_visitors['visitors'].fillna(0).astype(int)

# %%
# Replace empty values with 0
domestic_visitors['visitors'] = domestic_visitors['visitors'].replace('', '0')
foreign_visitors['visitors'] = foreign_visitors['visitors'].replace('', '0')


# Convert 'visitors' column to integers
domestic_visitors['visitors'] = domestic_visitors['visitors'].astype(int)
foreign_visitors['visitors'] = foreign_visitors['visitors'].astype(int)

# %% [markdown]
# ## First Question

# %% [markdown]
# ### Top 10 District With Highest Domestic Visitors

# %%
total_domestic_visitors=domestic_visitors.groupby('district')['visitors'].sum()
total_domestic_visitors.sort_values(ascending= False)[:10]
# Out:
# district
# Hyderabad                   83900960
# Rajanna Sircilla            41763276
# Warangal (Urban)            30726603
# Yadadri Bhongir             26893080
# Bhadradri Kothagudem        21600962
# Medak                       20542639
# Jayashankar Bhoopalpally    19632865
# Mahbubnagar                 17180118
# Nirmal                      13315796
# Jagtial                     11303514
# Name: visitors, dtype: int32

# %%
top_domestic= pd.DataFrame(total_domestic_visitors.sort_values(ascending= False)[:10]).reset_index()
top_domestic
# Out:
#                    district  visitors
# 0                 Hyderabad  83900960
# 1         Rajanna Sircilla   41763276
# 2          Warangal (Urban)  30726603
# 3           Yadadri Bhongir  26893080
# 4     Bhadradri Kothagudem   21600962
# 5                    Medak   20542639
# 6  Jayashankar Bhoopalpally  19632865
# 7               Mahbubnagar  17180118
# 8                    Nirmal  13315796
# 9                  Jagtial   11303514

# %%
# Set a custom color palette
colors = sns.color_palette('Spectral')
sns.set_theme(style="whitegrid", palette='Spectral')

# Set the figure size
plt.figure(figsize=(20, 9))
plt.suptitle("Top 10 district with highest Domestic Visitors", fontsize=28)

sns.barplot(x='visitors', y='district', data=top_domestic, palette=colors)

# Set the axis labels and plot title for df
plt.xlabel('Visitors', fontsize=24, fontweight='bold')
plt.ylabel('District', fontsize=24, fontweight='bold')


sns.despine()

plt.xticks(fontsize=22)
plt.yticks(fontsize=22)


sns.despine()

plt.xticks(fontsize=24)
plt.yticks(fontsize=24)

plt.tight_layout()


# Show the plot
plt.show()

# %% [markdown]
# ## Second Question

# %%
new_domestic_visitors= pd.DataFrame(domestic_visitors.groupby(['district','year'])['visitors'].sum()).reset_index()
new_domestic_visitors[:20]
# Out:
#                  district  year  visitors
# 0                Adilabad  2016   5075557
# 1                Adilabad  2017    825380
# 2                Adilabad  2018    644743
# 3                Adilabad  2019    775895
# 4   Bhadradri Kothagudem   2016    889030
# 5   Bhadradri Kothagudem   2017   4094317
# 6   Bhadradri Kothagudem   2018   3799878
# 7   Bhadradri Kothagudem   2019  12817737
# 8               Hyderabad  2016  23394705
# 9               Hyderabad  2017  27160242
# 10              Hyderabad  2018  19543651
# 11              Hyderabad  2019  13802362
# 12               Jagtial   2016    623077
# 13               Jagtial   2017   3641401
# 14               Jagtial   2018   3952921
# 15               Jagtial   2019   3086115
# 16               Jangaon   2016     40660
# 17               Jangaon   2017    165708
# 18               Jangaon   2018    291022
# 19               Jangaon   2019    328890

# %%
new_domestic_visitors[new_domestic_visitors['district']=='Komaram Bheem Asifabad']
# Out:
#                   district  year  visitors
# 40  Komaram Bheem Asifabad  2016         0
# 41  Komaram Bheem Asifabad  2017     50991
# 42  Komaram Bheem Asifabad  2018     22554
# 43  Komaram Bheem Asifabad  2019     19189

# %%
new_domestic_visitors['visitors'].value_counts()
# Out:
# 0          17
# 5075557     1
# 916610      1
# 22254       1
# 14898       1
#            ..
# 123976      1
# 9167468     1
# 534         1
# 572         1
# 4489374     1
# Name: visitors, Length: 110, dtype: int64

# %%
new_foreign_visitors= pd.DataFrame(foreign_visitors.groupby(['district','year'])['visitors'].sum()).reset_index()
new_foreign_visitors[:20]
# Out:
#                  district  year  visitors
# 0                Adilabad  2016        10
# 1                Adilabad  2017        11
# 2                Adilabad  2018         5
# 3                Adilabad  2019         6
# 4   Bhadradri Kothagudem   2016         0
# 5   Bhadradri Kothagudem   2017         0
# 6   Bhadradri Kothagudem   2018         0
# 7   Bhadradri Kothagudem   2019         0
# 8               Hyderabad  2016    163631
# 9               Hyderabad  2017    247179
# 10              Hyderabad  2018    314788
# 11              Hyderabad  2019    319300
# 12               Jagtial   2016         0
# 13               Jagtial   2017         0
# 14               Jagtial   2018         0
# 15               Jagtial   2019         0
# 16               Jangaon   2016         2
# 17               Jangaon   2017         0
# 18               Jangaon   2018         0
# 19               Jangaon   2019         0

# %%
new_foreign_visitors['visitors'].value_counts()
# Out:
# 0         89
# 2          4
# 45         2
# 10         2
# 5          2
# 1842       1
# 2630       1
# 1899       1
# 306        1
# 1          1
# 520        1
# 199        1
# 222        1
# 311        1
# 29         1
# 575        1
# 440        1
# 454        1
# 295        1
# 868        1
# 11         1
# 300        1
# 305        1
# 539        1
# 582        1
# 86         1
# 319300     1
# 314788     1
# 247179     1
# 163631     1
# 6          1
# 2450       1
# Name: visitors, dtype: int64

# %%
new_domestic_visitors['visitors'] = new_domestic_visitors['visitors'].replace(0, 1)
new_foreign_visitors['visitors'] = new_foreign_visitors['visitors'].replace(0, 1)

# %%
new_foreign_visitors['visitors'].value_counts()
# Out:
# 1         90
# 2          4
# 10         2
# 5          2
# 45         2
# 222        1
# 440        1
# 575        1
# 29         1
# 311        1
# 199        1
# 520        1
# 306        1
# 1899       1
# 2630       1
# 1842       1
# 454        1
# 300        1
# 868        1
# 295        1
# 11         1
# 305        1
# 539        1
# 582        1
# 86         1
# 319300     1
# 314788     1
# 247179     1
# 163631     1
# 6          1
# 2450       1
# Name: visitors, dtype: int64

# %% [markdown]
# ## Rename

# %%
new_foreign_visitors=new_foreign_visitors.rename(columns={'visitors': 'foreign visitors'})

# %%
new_domestic_visitors
# Out:
#                   district  year  visitors
# 0                 Adilabad  2016   5075557
# 1                 Adilabad  2017    825380
# 2                 Adilabad  2018    644743
# 3                 Adilabad  2019    775895
# 4    Bhadradri Kothagudem   2016    889030
# ..                     ...   ...       ...
# 121       Warangal (Urban)  2019   1795230
# 122        Yadadri Bhongir  2016   1728600
# 123        Yadadri Bhongir  2017   7001728
# 124        Yadadri Bhongir  2018  13673378
# 125        Yadadri Bhongir  2019   4489374
#
# [126 rows x 3 columns]

# %%
new_foreign_visitors
# Out:
#                   district  year  foreign visitors
# 0                 Adilabad  2016                10
# 1                 Adilabad  2017                11
# 2                 Adilabad  2018                 5
# 3                 Adilabad  2019                 6
# 4    Bhadradri Kothagudem   2016                 1
# ..                     ...   ...               ...
# 121       Warangal (Urban)  2019              2450
# 122        Yadadri Bhongir  2016                 1
# 123        Yadadri Bhongir  2017                 1
# 124        Yadadri Bhongir  2018                 1
# 125        Yadadri Bhongir  2019                 1
#
# [126 rows x 3 columns]

# %%
top_domestic=new_domestic_visitors.sort_values(by=['visitors'], ascending= False)[:10].reset_index(drop=True)
top_domestic
# Out:
#                    district  year  visitors
# 0                 Hyderabad  2017  27160242
# 1          Warangal (Urban)  2016  25788035
# 2                 Hyderabad  2016  23394705
# 3                 Hyderabad  2018  19543651
# 4  Jayashankar Bhoopalpally  2018  16895925
# 5         Rajanna Sircilla   2019  16832897
# 6                 Hyderabad  2019  13802362
# 7           Yadadri Bhongir  2018  13673378
# 8     Bhadradri Kothagudem   2019  12817737
# 9         Rajanna Sircilla   2017  11919347

# %% [markdown]
# ## JOIN

# %%
# Perform an inner join on district and year columns
year_wise_visitors = pd.merge(new_domestic_visitors, new_foreign_visitors, on=['district', 'year'], how='inner')
year_wise_visitors
# Out:
#                   district  year  visitors  foreign visitors
# 0                 Adilabad  2016   5075557                10
# 1                 Adilabad  2017    825380                11
# 2                 Adilabad  2018    644743                 5
# 3                 Adilabad  2019    775895                 6
# 4    Bhadradri Kothagudem   2016    889030                 1
# ..                     ...   ...       ...               ...
# 120       Warangal (Urban)  2019   1795230              2450
# 121        Yadadri Bhongir  2016   1728600                 1
# 122        Yadadri Bhongir  2017   7001728                 1
# 123        Yadadri Bhongir  2018  13673378                 1
# 124        Yadadri Bhongir  2019   4489374                 1
#
# [125 rows x 4 columns]

# %%
year_wise_visitors['total visitors']= year_wise_visitors['visitors'] + year_wise_visitors['foreign visitors']
year_wise_visitors
# Out:
#                   district  year  visitors  foreign visitors  total visitors
# 0                 Adilabad  2016   5075557                10         5075567
# 1                 Adilabad  2017    825380                11          825391
# 2                 Adilabad  2018    644743                 5          644748
# 3                 Adilabad  2019    775895                 6          775901
# 4    Bhadradri Kothagudem   2016    889030                 1          889031
# ..                     ...   ...       ...               ...             ...
# 120       Warangal (Urban)  2019   1795230              2450         1797680
# 121        Yadadri Bhongir  2016   1728600                 1         1728601
# 122        Yadadri Bhongir  2017   7001728                 1         7001729
# 123        Yadadri Bhongir  2018  13673378                 1        13673379
# 124        Yadadri Bhongir  2019   4489374                 1         4489375
#
# [125 rows x 5 columns]

# %%
print(year_wise_visitors[['district','year', 'total visitors']][:20])
# Out:
#                  district  year  total visitors
# 0                Adilabad  2016         5075567
# 1                Adilabad  2017          825391
# 2                Adilabad  2018          644748
# 3                Adilabad  2019          775901
# 4   Bhadradri Kothagudem   2016          889031
# 5   Bhadradri Kothagudem   2017         4094318
# 6   Bhadradri Kothagudem   2018         3799879
# 7   Bhadradri Kothagudem   2019        12817738
# 8               Hyderabad  2016        23558336
# 9               Hyderabad  2017        27407421
# 10              Hyderabad  2018        19858439
# 11              Hyderabad  2019        14121662
# 12               Jagtial   2016          623078
# 13               Jagtial   2017         3641402
# 14               Jagtial   2018         3952922
# 15               Jagtial   2019         3086116
# 16               Jangaon   2016           40662
# 17               Jangaon   2017          165709
# 18               Jangaon   2018          291023
# ...

# %%
year_wise_visitors.dtypes
# Out:
# district            object
# year                 int64
# visitors             int32
# foreign visitors     int32
# total visitors       int32
# dtype: object

# %%
year_wise_visitors['district'].unique()
# Out:
# array(['Adilabad', 'Bhadradri Kothagudem ', 'Hyderabad', 'Jagtial ',
#        'Jangaon ', 'Jayashankar Bhoopalpally', 'Jogulamba Gadwal ',
#        'Kamareddy ', 'Karimnagar ', 'Khammam', 'Komaram Bheem Asifabad',
#        'Mahabubabad ', 'Mahbubnagar', 'Mancherial', 'Medak ', 'Medchal ',
#        'Mulugu', 'Nagarkurnool ', 'Nalgonda', 'Nirmal', 'Nizamabad',
#        'Peddapalli', 'Rajanna Sircilla ', 'Ranga Reddy', 'Sangareddy ',
#        'Siddipet', 'Suryapet', 'Vikarabad', 'Wanaparthy ',
#        'Warangal (Rural)', 'Warangal (Urban)', 'Yadadri Bhongir'],
#       dtype=object)

# %%
year_wise_visitors['year'].unique()
# Out:
# array([2016, 2017, 2018, 2019], dtype=int64)

# %% [markdown]
# ## CAGR

# %%
# Group the dataframe by 'district'
grouped = year_wise_visitors.groupby('district')

# Calculate CAGR for each district
cagr_df = pd.DataFrame(columns=['district', 'CAGR'])

for district, data in grouped:
    beginning_value = data.iloc[0]['total visitors']
    ending_value = data.iloc[-1]['total visitors']
    num_years = len(data)
    
    cagr = (ending_value / beginning_value) ** (1 / num_years) - 1
    
    cagr_df = cagr_df.append({'district': district, 'CAGR': cagr}, ignore_index=True)

# Display the dataframe with CAGR values
cagr_df.sort_values(by=['CAGR'], ascending= False, inplace=True)
cagr_df.reset_index(drop=True, inplace=True)
cagr_df
# Out:
# C:\Users\Subhojit\AppData\Local\Temp\ipykernel_3956\3213881155.py:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   cagr_df = cagr_df.append({'district': district, 'CAGR': cagr}, ignore_index=True)
# C:\Users\Subhojit\AppData\Local\Temp\ipykernel_3956\3213881155.py:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   cagr_df = cagr_df.append({'district': district, 'CAGR': cagr}, ignore_index=True)
# C:\Users\Subhojit\AppData\Local\Temp\ipykernel_3956\3213881155.py:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   cagr_df = cagr_df.append({'district': district, 'CAGR': cagr}, ignore_index=True)
# ...

# %% [markdown]
# ### Top 3 districts with CAGR

# %%
highest_cagr= cagr_df[:3]
lowest_cagr= cagr_df[-3:]

# %%
# Set a custom color palette
colors = sns.color_palette('Spectral')
sns.set_theme(style="whitegrid", palette='Spectral')

# Set the figure size
plt.figure(figsize=(20, 9))
plt.suptitle("District Wise CAGR", fontsize=28)

# Create the first subplot for df
plt.subplot(1, 2, 1)
sns.barplot(x='district', y='CAGR', data=highest_cagr, palette=colors)

plt.xlabel('District', fontsize=24, fontweight='bold')
plt.ylabel('CAGR', fontsize=24, fontweight='bold')
plt.title('Highest', fontsize=24, fontweight='bold')


sns.despine()

plt.xticks(fontsize=22)
plt.yticks(fontsize=22)

plt.subplot(1, 2, 2)
sns.barplot(x='district', y='CAGR', data=lowest_cagr, palette=colors)


plt.xlabel('District', fontsize=22, fontweight='bold')
plt.ylabel('')
plt.title('Lowest', fontsize=22, fontweight='bold')

# Set the y-label formatting as whole numbers
plt.ticklabel_format(style='plain', axis='y')


sns.despine()

# Set the tick sizes for dfx
plt.xticks(fontsize=24)
plt.yticks(fontsize=24)

# Adjust the plot layout
plt.tight_layout()


# Show the plot
plt.show()

# %% [markdown]
# ## Season

# %%
domestic_visitors
# Out:
#             district        date      month  year  visitors
# 0           Adilabad  01-01-2016    January  2016    792136
# 1           Adilabad  01-02-2016   February  2016    937820
# 2           Adilabad  01-03-2016      March  2016    582946
# 3           Adilabad  01-04-2016      April  2016    341948
# 4           Adilabad  01-05-2016        May  2016    252887
# ..               ...         ...        ...   ...       ...
# 391  Yadadri Bhongir  01-08-2019     August  2019    389010
# 392  Yadadri Bhongir  01-09-2019  September  2019    366862
# 393  Yadadri Bhongir  01-10-2019    October  2019    381860
# 394  Yadadri Bhongir  01-11-2019   November  2019    365990
# 395  Yadadri Bhongir  01-12-2019   December  2019    477635
#
# [1512 rows x 5 columns]

# %%
foreign_visitors
# Out:
#             district        date      month  year  visitors
# 0           Adilabad  01-01-2016    January  2016         2
# 1           Adilabad  01-02-2016   February  2016         0
# 2           Adilabad  01-03-2016      March  2016         2
# 3           Adilabad  01-04-2016      April  2016         0
# 4           Adilabad  01-05-2016        May  2016         0
# ..               ...         ...        ...   ...       ...
# 391  Yadadri Bhongir  01-08-2019     August  2019         0
# 392  Yadadri Bhongir  01-09-2019  September  2019         0
# 393  Yadadri Bhongir  01-10-2019    October  2019         0
# 394  Yadadri Bhongir  01-11-2019   November  2019         0
# 395  Yadadri Bhongir  01-12-2019   December  2019         0
#
# [1512 rows x 5 columns]

# %%
month_wise_domestic= pd.DataFrame(domestic_visitors.groupby(['district','month'])['visitors'].sum()).reset_index()
month_wise_foreign= pd.DataFrame(foreign_visitors.groupby(['district','month'])['visitors'].sum()).reset_index()

# %%
month_wise_foreign=month_wise_foreign.rename(columns={'visitors': 'foreign visitors'})

# %%
month_wise_visitors= pd.merge(month_wise_domestic, month_wise_foreign, on=['district', 'month'], how='inner')
month_wise_visitors['total visitors']= month_wise_visitors['visitors'] + month_wise_visitors['foreign visitors']
month_wise_visitors
# Out:
#             district      month  visitors  foreign visitors  total visitors
# 0           Adilabad      April    380049                 0          380049
# 1           Adilabad     August    796273                 7          796280
# 2           Adilabad   December    206941                 0          206941
# 3           Adilabad   February   1463863                 2         1463865
# 4           Adilabad    January   1456362                 7         1456369
# ..               ...        ...       ...               ...             ...
# 379  Yadadri Bhongir      March   3844091                 0         3844091
# 380  Yadadri Bhongir        May   1586332                 0         1586332
# 381  Yadadri Bhongir   November   2069798                 0         2069798
# 382  Yadadri Bhongir    October   2236635                 0         2236635
# 383  Yadadri Bhongir  September   1865137                 0         1865137
#
# [384 rows x 5 columns]

# %%
hyderabad_visitors= month_wise_visitors[month_wise_visitors['district'] == 'Hyderabad']
hyderabad_visitors.sort_values(by=['total visitors'], ascending= False, inplace= True)
hyderabad_visitors.reset_index(drop= True, inplace= True)
hyderabad_visitors
# Out:
# C:\Users\Subhojit\AppData\Local\Temp\ipykernel_3956\1007749370.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   hyderabad_visitors.sort_values(by=['total visitors'], ascending= False, inplace= True)
#      district      month  visitors  foreign visitors  total visitors
# 0   Hyderabad       June  16897783             67524        16965307
# 1   Hyderabad   December   9338637            119995         9458632
# 2   Hyderabad    October   6552397             97954         6650351
# 3   Hyderabad    January   6452101            106450         6558551
# 4   Hyderabad      April   6126839             60495         6187334
# 5   Hyderabad        May   6049214             60376         6109590
# 6   Hyderabad     August   5750967             83769         5834736
# ...

# %%
# Define the desired order of months
month_order = ['January', 'February', 'March', 'April', 'May', 'June', 'July', 'August', 'September', 'October', 'November', 'December']

# Convert the 'month' column to a categorical data type with the desired order
hyderabad_visitors['month'] = pd.Categorical(hyderabad_visitors['month'], categories=month_order, ordered=True)

# Sort the dataframe by the 'month' column
hyderabad_visitors_sorted = hyderabad_visitors.sort_values('month')
hyderabad_visitors_sorted
# Out:
# C:\Users\Subhojit\AppData\Local\Temp\ipykernel_3956\1945712009.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   hyderabad_visitors['month'] = pd.Categorical(hyderabad_visitors['month'], categories=month_order, ordered=True)
#      district      month  visitors  foreign visitors  total visitors
# 3   Hyderabad    January   6452101            106450         6558551
# 11  Hyderabad   February   5014430            103778         5118208
# 10  Hyderabad      March   5227626             76358         5303984
# 4   Hyderabad      April   6126839             60495         6187334
# 5   Hyderabad        May   6049214             60376         6109590
# 0   Hyderabad       June  16897783             67524        16965307
# ...

# %%
# Set a custom color palette
colors = sns.color_palette('Spectral')
sns.set_theme(style="whitegrid", palette='Spectral')

# Set the figure size
plt.figure(figsize=(20, 9))
plt.suptitle("Hyderabad Visitors Season Wise", fontsize=28)

sns.lineplot(x='month', y='total visitors', data=hyderabad_visitors, palette=colors)

# Set the axis labels and plot title for df
plt.xlabel('Month', fontsize=24, fontweight='bold')
plt.ylabel('Visitors', fontsize=24, fontweight='bold')

# Set the y-label formatting as whole numbers
plt.ticklabel_format(style='plain', axis='y')


sns.despine()

plt.xticks(fontsize=22)
plt.yticks(fontsize=22)


sns.despine()

plt.xticks(fontsize=24)
plt.yticks(fontsize=24)

plt.tight_layout()


# Show the plot
plt.show()

# %% [markdown]
# ## Ratio

# %%
ratio= year_wise_visitors.drop(columns=['year'])
ratio=ratio.groupby('district')['visitors', 'foreign visitors', 'total visitors'].sum()
ratio=ratio.reset_index(drop= False)
ratio
# Out:
# C:\Users\Subhojit\AppData\Local\Temp\ipykernel_3956\689935591.py:2: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   ratio=ratio.groupby('district')['visitors', 'foreign visitors', 'total visitors'].sum()
#                     district  visitors  foreign visitors  total visitors
# 0                   Adilabad   7321575                32         7321607
# 1      Bhadradri Kothagudem   21600962                 4        21600966
# 2                  Hyderabad  83900960           1044898        84945858
# 3                   Jagtial   11303514                 4        11303518
# 4                   Jangaon     826280                 5          826285
# 5   Jayashankar Bhoopalpally  19632865              1252        19634117
# 6          Jogulamba Gadwal    6813340               945         6814285
# 7                 Kamareddy       1773                 4            1777
# ...

# %%
# Set the desired float format
pd.options.display.float_format = '{:.2f}'.format

ratio['df_ratio']= ratio['visitors'] / ratio['foreign visitors']
ratio.sort_values(by=['df_ratio'], ascending=False)
# Out:
#                     district  visitors  foreign visitors  total visitors  \
# 22         Rajanna Sircilla   41763276                 4        41763280
# 31           Yadadri Bhongir  26893080                 4        26893084
# 1      Bhadradri Kothagudem   21600962                 4        21600966
# 14                    Medak   20542639                 4        20542643
# 3                   Jagtial   11303514                 4        11303518
# 19                    Nirmal  13315796                 5        13315801
# 24               Sangareddy   10424510                 4        10424514
# 8                Karimnagar    9462383                 4         9462387
# 9                    Khammam   9378315                 4         9378319
# 18                  Nalgonda   6401933                 4         6401937
# 25                  Siddipet   5775285                 4         5775289
# 0                   Adilabad   7321575                32         7321607
# ...

# %%
domestic= pd.DataFrame(total_domestic_visitors)
domestic=domestic.reset_index()
domestic
# Out:
#                     district  visitors
# 0                   Adilabad   7321575
# 1      Bhadradri Kothagudem   21600962
# 2                  Hyderabad  83900960
# 3                   Jagtial   11303514
# 4                   Jangaon     826280
# 5   Jayashankar Bhoopalpally  19632865
# 6          Jogulamba Gadwal    6813340
# 7                 Kamareddy       1773
# 8                Karimnagar    9462383
# 9                    Khammam   9378315
# 10    Komaram Bheem Asifabad     92734
# 11              Mahabubabad     600697
# 12               Mahbubnagar  17180118
# 13                Mancherial    867242
# 14                    Medak   20542639
# 15                  Medchal          0
# 16                    Mulugu   1819800
# 17             Nagarkurnool    7424355
# 18                  Nalgonda   6401933
# 19               Narayanapet    389250
# 20                    Nirmal  13315796
# 21                 Nizamabad    116147
# 22                Peddapalli     56977
# ...

# %%
total_foreign_visitors=foreign_visitors.groupby('district')['visitors'].sum()
total_foreign_visitors
# Out:
# district
# Adilabad                         32
# Bhadradri Kothagudem              0
# Hyderabad                   1044898
# Jagtial                           0
# Jangaon                           2
# Jayashankar Bhoopalpally       1252
# Jogulamba Gadwal                945
# Kamareddy                         0
# Karimnagar                        0
# Khammam                           0
# Komaram Bheem Asifabad            0
# Mahabubabad                       0
# Mahbubnagar                    2282
# Mancherial                       10
# Medak                             0
# Medchal                           0
# Mulugu                          575
# Nagarkurnool                    761
# Nalgonda                          0
# Narayanpet                        5
# Nirmal                            2
# Nizamabad                         5
# Peddapalli                        0
# Rajanna Sircilla                  0
# Ranga Reddy                       0
# Sangareddy                        0
# ...

# %%
foreign= pd.DataFrame(total_foreign_visitors)
foreign=foreign.reset_index(drop= False)
foreign.rename(columns={'visitors': 'foreign visitors'},inplace= True)
foreign
# Out:
#                     district  foreign visitors
# 0                   Adilabad                32
# 1      Bhadradri Kothagudem                  0
# 2                  Hyderabad           1044898
# 3                   Jagtial                  0
# 4                   Jangaon                  2
# 5   Jayashankar Bhoopalpally              1252
# 6          Jogulamba Gadwal                945
# 7                 Kamareddy                  0
# 8                Karimnagar                  0
# 9                    Khammam                 0
# 10    Komaram Bheem Asifabad                 0
# 11              Mahabubabad                  0
# 12               Mahbubnagar              2282
# 13                Mancherial                10
# 14                    Medak                  0
# 15                  Medchal                  0
# 16                    Mulugu               575
# 17             Nagarkurnool                761
# 18                  Nalgonda                 0
# ...

# %%
ratio= pd.merge(domestic, foreign, on=['district'], how='inner')
ratio
# Out:
#                     district  visitors  foreign visitors
# 0                   Adilabad   7321575                32
# 1      Bhadradri Kothagudem   21600962                 0
# 2                  Hyderabad  83900960           1044898
# 3                   Jagtial   11303514                 0
# 4                   Jangaon     826280                 2
# 5   Jayashankar Bhoopalpally  19632865              1252
# 6          Jogulamba Gadwal    6813340               945
# 7                 Kamareddy       1773                 0
# 8                Karimnagar    9462383                 0
# 9                    Khammam   9378315                 0
# 10    Komaram Bheem Asifabad     92734                 0
# 11              Mahabubabad     600697                 0
# 12               Mahbubnagar  17180118              2282
# 13                Mancherial    867242                10
# 14                    Medak   20542639                 0
# ...

# %%
ratio =ratio.replace(0,1)
ratio
# Out:
#                     district  visitors  foreign visitors
# 0                   Adilabad   7321575                32
# 1      Bhadradri Kothagudem   21600962                 1
# 2                  Hyderabad  83900960           1044898
# 3                   Jagtial   11303514                 1
# 4                   Jangaon     826280                 2
# 5   Jayashankar Bhoopalpally  19632865              1252
# 6          Jogulamba Gadwal    6813340               945
# 7                 Kamareddy       1773                 1
# 8                Karimnagar    9462383                 1
# 9                    Khammam   9378315                 1
# 10    Komaram Bheem Asifabad     92734                 1
# 11              Mahabubabad     600697                 1
# 12               Mahbubnagar  17180118              2282
# 13                Mancherial    867242                10
# 14                    Medak   20542639                 1
# ...

# %%
# Set the desired float format
pd.options.display.float_format = '{:.2f}'.format

ratio['df_ratio']= ratio['visitors'] / ratio['foreign visitors']
ratio.sort_values(by=['df_ratio'], ascending=False)
# Out:
#                     district  visitors  foreign visitors    df_ratio
# 22         Rajanna Sircilla   41763276                 1 41763276.00
# 31           Yadadri Bhongir  26893080                 1 26893080.00
# 1      Bhadradri Kothagudem   21600962                 1 21600962.00
# 14                    Medak   20542639                 1 20542639.00
# 3                   Jagtial   11303514                 1 11303514.00
# 24               Sangareddy   10424510                 1 10424510.00
# 8                Karimnagar    9462383                 1  9462383.00
# 9                    Khammam   9378315                 1  9378315.00
# 19                    Nirmal  13315796                 2  6657898.00
# 18                  Nalgonda   6401933                 1  6401933.00
# 25                  Siddipet   5775285                 1  5775285.00
# 28               Wanaparthy     890078                 1   890078.00
# 11              Mahabubabad     600697                 1   600697.00
# ...

# %%
top_ratio= ratio.sort_values(by=['df_ratio'], ascending=False)[:3]
bottom_ratio= ratio.sort_values(by=['df_ratio'], ascending=False)[-3:]

# %%
year_wise_visitors_2019= year_wise_visitors[year_wise_visitors['year']==2019]
year_wise_visitors_2019= year_wise_visitors_2019.reset_index(drop= True)
year_wise_visitors_2019
# Out:
#                     district  year  visitors  foreign visitors  total visitors
# 0                   Adilabad  2019    775895                 6          775901
# 1      Bhadradri Kothagudem   2019  12817737                 1        12817738
# 2                  Hyderabad  2019  13802362            319300        14121662
# 3                   Jagtial   2019   3086115                 1         3086116
# 4                   Jangaon   2019    328890                 1          328891
# 5   Jayashankar Bhoopalpally  2019    662530                45          662575
# 6          Jogulamba Gadwal   2019   2007995               295         2008290
# 7                 Kamareddy   2019       534                 1             535
# 8                Karimnagar   2019     77491                 1           77492
# 9                    Khammam  2019   1413440                 1         1413441
# 10    Komaram Bheem Asifabad  2019     19189                 1           19190
# ...

# %%
# Set a custom color palette
colors = sns.color_palette('Spectral')
sns.set_theme(style="whitegrid", palette='Spectral')

# Set the figure size
plt.figure(figsize=(20, 9))
plt.suptitle("Domestic Vs. Foreign Ratio", fontsize=28)

# Create the first subplot for df
plt.subplot(1, 2, 1)
sns.barplot(x='district', y='df_ratio', data=top_ratio, palette=colors)

plt.xlabel('District', fontsize=24, fontweight='bold')
plt.ylabel('Ratio Value', fontsize=24, fontweight='bold')
plt.title('Highest', fontsize=24, fontweight='bold')


sns.despine()

plt.xticks(fontsize=22)
plt.yticks(fontsize=22)

# Set the y-label formatting as whole numbers
plt.ticklabel_format(style='plain', axis='y')

plt.subplot(1, 2, 2)
sns.barplot(x='district', y='df_ratio', data=bottom_ratio, palette=colors)


plt.xlabel('District', fontsize=22, fontweight='bold')
plt.ylabel('')
plt.title('Lowest', fontsize=22, fontweight='bold')


sns.despine()

# Set the tick sizes for dfx
plt.xticks(fontsize=24)
plt.yticks(fontsize=24)

# Adjust the plot layout
plt.tight_layout()


# Show the plot
plt.show()

# %% [markdown]
# # Secondary Questions

# %%
telengana= pd.read_excel(r"D:\Data Study materials\C5 Input for participants\telengana population 2011.xlsx")
telengana.rename(columns={'District Name': 'district'}, inplace=True)
telengana.set_index('district', inplace=True)
telengana.reset_index(drop=False, inplace=True)
telengana['district'] = telengana['district'].str.strip()
telengana
# Out:
#                    district  Population 2011
# 0                  Adilabad            708972
# 1      Bhadradri Kothagudem           1069261
# 2                 Hyderabad           3943323
# 3                  Jagitial            985417
# 4                   Jangaon            566376
# 5   Jayashankar Bhupalpally            416763
# 6          Jogulamba Gadwal            609990
# 7                 Kamareddy            972625
# 8                Karimnagar           1005711
# 9                   Khammam           1401639
# 10            Komaram Bheem            515812
# 11              Mahabubabad            774549
# 12              Mahbubnagar            919903
# 13               Mancherial            807037
# 14                    Medak            767428
# 15       Medchal–Malkajgiri           2440073
# 16                   Mulugu            257744
# 17             Nagarkurnool            893308
# 18                 Nalgonda           1618416
# ...

# %%
ratio['district'] = ratio['district'].str.strip()

# %%
ratio['district'].values
# Out:
# array(['Adilabad', 'Bhadradri Kothagudem', 'Hyderabad', 'Jagtial',
#        'Jangaon', 'Jayashankar Bhoopalpally', 'Jogulamba Gadwal',
#        'Kamareddy', 'Karimnagar', 'Khammam', 'Komaram Bheem Asifabad',
#        'Mahabubabad', 'Mahbubnagar', 'Mancherial', 'Medak', 'Medchal',
#        'Mulugu', 'Nagarkurnool', 'Nalgonda', 'Nirmal', 'Nizamabad',
#        'Peddapalli', 'Rajanna Sircilla', 'Ranga Reddy', 'Sangareddy',
#        'Siddipet', 'Suryapet', 'Vikarabad', 'Wanaparthy',
#        'Warangal (Rural)', 'Warangal (Urban)', 'Yadadri Bhongir'],
#       dtype=object)

# %%
telengana=telengana.replace('Jagitial','Jagtial')
#telengana = telengana.drop('Narayanpet', axis=0)
telengana=telengana.replace( 'Warangal Rural', 'Warangal (Rural)')
telengana=telengana.replace( 'Warangal Urban', 'Warangal (Urban)')
telengana=telengana.replace( 'Medchal–Malkajgiri', 'Medchal')
telengana=telengana.replace(  'Komaram Bheem','Komaram Bheem Asifabad')
telengana=telengana.replace(  'Yadadri Bhuvanagiri','Yadadri Bhongir')
telengana=telengana.replace('Mahabubnagar', 'Mahbubnagar')
telengana=telengana.replace('Jayashankar Bhupalpally','Jayashankar Bhoopalpally')

# %%
first_list = ratio['district'].unique()
second_list = telengana['district'].unique()

# Find the value in the second list that is not in the first list
difference = set(second_list) - set(first_list)

# Convert the set to a list
result = list(difference)

print(result)
print(len(result))
# Out:
# ['Narayanpet']
# 1

# %%
ratio_with_population= pd.merge(ratio, telengana, on=['district'], how='inner')
ratio_with_population['total visitors']= ratio_with_population['visitors'] + ratio_with_population['foreign visitors']
ratio_with_population
# Out:
#                     district  visitors  foreign visitors    df_ratio  \
# 0                   Adilabad   7321575                32   228799.22
# 1       Bhadradri Kothagudem  21600962                 1 21600962.00
# 2                  Hyderabad  83900960           1044898       80.30
# 3                    Jagtial  11303514                 1 11303514.00
# 4                    Jangaon    826280                 2   413140.00
# 5   Jayashankar Bhoopalpally  19632865              1252    15681.20
# 6           Jogulamba Gadwal   6813340               945     7209.88
# 7                  Kamareddy      1773                 1     1773.00
# 8                 Karimnagar   9462383                 1  9462383.00
# 9                    Khammam   9378315                 1  9378315.00
# 10    Komaram Bheem Asifabad     92734                 1    92734.00
# 11               Mahabubabad    600697                 1   600697.00
# 12               Mahbubnagar  17180118              2282     7528.54
# ...

# %%
ratio_with_population['vp_ratio']= ratio_with_population['Population 2011 '] / ratio_with_population['total visitors']
ratio_with_population.sort_values(by='vp_ratio', ascending= False)
# Out:
#                     district  visitors  foreign visitors    df_ratio  \
# 23               Ranga Reddy         1                 1        1.00
# 15                   Medchal         1                 1        1.00
# 26                  Suryapet         1                 1        1.00
# 27                 Vikarabad         1                 1        1.00
# 7                  Kamareddy      1773                 1     1773.00
# 21                Peddapalli     56977                 1    56977.00
# 20                 Nizamabad    116147                 5    23229.40
# 10    Komaram Bheem Asifabad     92734                 1    92734.00
# 11               Mahabubabad    600697                 1   600697.00
# 13                Mancherial    867242                10    86724.20
# 29          Warangal (Rural)    819162               306     2677.00
# 4                    Jangaon    826280                 2   413140.00
# 28                Wanaparthy    890078                 1   890078.00
# ...

# %%
ratio_with_population_2019= pd.merge(year_wise_visitors_2019, telengana, on=['district'], how='inner')
ratio_with_population_2019['total visitors']= ratio_with_population_2019['visitors'] + ratio_with_population_2019['foreign visitors']
ratio_with_population_2019
# Out:
#                     district  year  visitors  foreign visitors  \
# 0                   Adilabad  2019    775895                 6
# 1                  Hyderabad  2019  13802362            319300
# 2   Jayashankar Bhoopalpally  2019    662530                45
# 3                    Khammam  2019   1413440                 1
# 4     Komaram Bheem Asifabad  2019     19189                 1
# 5                Mahbubnagar  2019   2534815               440
# 6                 Mancherial  2019    269810                10
# 7                     Mulugu  2019   1819800               575
# 8                   Nalgonda  2019    140918                 1
# 9                     Nirmal  2019   3816778                 1
# 10                 Nizamabad  2019     46333                 1
# 11                Peddapalli  2019     16581                 1
# 12               Ranga Reddy  2019         1                 1
# 13                  Siddipet  2019   2987864                 1
# ...

# %%
ratio_with_population_2019['vp_ratio']= ratio_with_population_2019['Population 2011 '] / ratio_with_population_2019['total visitors']
ratio_with_population_2019.sort_values(by='vp_ratio', ascending= False)
# Out:
#                     district  year  visitors  foreign visitors  \
# 12               Ranga Reddy  2019         1                 1
# 14                  Suryapet  2019         1                 1
# 15                 Vikarabad  2019         1                 1
# 11                Peddapalli  2019     16581                 1
# 10                 Nizamabad  2019     46333                 1
# 4     Komaram Bheem Asifabad  2019     19189                 1
# 8                   Nalgonda  2019    140918                 1
# 6                 Mancherial  2019    269810                10
# 16          Warangal (Rural)  2019    353500                 1
# 3                    Khammam  2019   1413440                 1
# 0                   Adilabad  2019    775895                 6
# 2   Jayashankar Bhoopalpally  2019    662530                45
# 17          Warangal (Urban)  2019   1795230              2450
# 5                Mahbubnagar  2019   2534815               440
# ...

# %%
top_vp_ratio= ratio_with_population_2019.sort_values(by='vp_ratio', ascending= False)[:5]
bottom_vp_ratio= ratio_with_population_2019.sort_values(by='vp_ratio', ascending= False)[-5:]

# %%
# Set a custom color palette
colors = sns.color_palette('Spectral')
sns.set_theme(style="whitegrid", palette='Spectral')

# Set the figure size
plt.figure(figsize=(20, 12))
plt.suptitle("District Wise Population to Tourist Ratio", fontsize=32)

# Create the first subplot for df
plt.subplot(1, 2, 1)
sns.barplot(x='district', y='vp_ratio', data=top_vp_ratio, palette=colors)

plt.xlabel('District', fontsize=24, fontweight='bold')
plt.ylabel('Ratio (Population Vs. Visitors)', fontsize=24, fontweight='bold')
plt.title('Highest', fontsize=24, fontweight='bold')

# Set the y-label formatting as whole numbers
plt.ticklabel_format(style='plain', axis='y')


sns.despine()

plt.xticks(fontsize=28, rotation= '90')
plt.yticks(fontsize=22)

plt.subplot(1, 2, 2)
sns.barplot(x='district', y='vp_ratio', data=bottom_vp_ratio, palette=colors)


plt.xlabel('District', fontsize=22, fontweight='bold')
plt.ylabel('')
plt.title('Lowest', fontsize=22, fontweight='bold')

# Set the y-label formatting as whole numbers
plt.ticklabel_format(style='plain', axis='y')


sns.despine()

# Set the tick sizes for dfx
plt.xticks(fontsize=28, rotation= '90')
plt.yticks(fontsize=24)

# Adjust the plot layout
plt.tight_layout()


# Show the plot
plt.show()

# %% [markdown]
# ## Hyderabad Domestic tourist by 2025 according to CAGR

# %%
cagr_df[cagr_df['district']== 'Hyderabad']
# Out:
#      district  CAGR
# 25  Hyderabad -0.12

# %%
hyderabad= year_wise_visitors[year_wise_visitors['district']== 'Hyderabad']
hyderabad
# Out:
#      district  year  visitors  foreign visitors  total visitors
# 8   Hyderabad  2016  23394705            163631        23558336
# 9   Hyderabad  2017  27160242            247179        27407421
# 10  Hyderabad  2018  19543651            314788        19858439
# 11  Hyderabad  2019  13802362            319300        14121662

# %%
print('Hyderabad Domestic Visitors in 2025 will be {:.0f}'.format(13802362*(1+(-0.12/100))**6))
print('Hyderabad Foreign Visitors in 2025 will be {:.0f}'.format(319300*(1+(-0.12/100))**6))
# Out:
# Hyderabad Domestic Visitors in 2025 will be 13703283
# Hyderabad Foreign Visitors in 2025 will be 317008

# %%
new_row = {'district': 'Hyderabad', 'year': 2025, 'visitors': 13703283, 'foreign visitors': 317008, 'total visitors': 13703283+317008}

hyderabad= hyderabad.append(new_row, ignore_index=True)

hyderabad
# Out:
# C:\Users\Subhojit\AppData\Local\Temp\ipykernel_3956\2037286526.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   hyderabad= hyderabad.append(new_row, ignore_index=True)
#     district  year  visitors  foreign visitors  total visitors
# 0  Hyderabad  2016  23394705            163631        23558336
# 1  Hyderabad  2017  27160242            247179        27407421
# 2  Hyderabad  2018  19543651            314788        19858439
# 3  Hyderabad  2019  13802362            319300        14121662
# 4  Hyderabad  2025  13703283            317008        14020291

# %%
# Set a custom color palette
colors = sns.color_palette('Spectral')
sns.set_theme(style="whitegrid", palette='Spectral')

# Set the figure size
plt.figure(figsize=(16,8))
plt.suptitle("Hyderabad Domestic Visitors Year Wise", fontsize=28)

sns.lineplot(x='year', y='visitors', data=hyderabad, palette=colors)

# Set the axis labels and plot title for df
plt.xlabel('Year', fontsize=24, fontweight='bold')
plt.ylabel('Visitors', fontsize=24, fontweight='bold')

# Set the y-label formatting as whole numbers
plt.ticklabel_format(style='plain', axis='y')


sns.despine()

plt.xticks(fontsize=22)
plt.yticks(fontsize=22)


sns.despine()

plt.xticks(fontsize=24)
plt.yticks(fontsize=24)

plt.tight_layout()


# Show the plot
plt.show()

# %%
# Set a custom color palette
colors = sns.color_palette('Spectral')
sns.set_theme(style="whitegrid", palette='Spectral')

# Set the figure size
plt.figure(figsize=(16,8))
plt.suptitle("Hyderabad Foreign Visitors Year Wise", fontsize=28)

sns.lineplot(x='year', y='foreign visitors', data=hyderabad, palette=colors)

# Set the axis labels and plot title for df
plt.xlabel('Year', fontsize=24, fontweight='bold')
plt.ylabel('Visitors', fontsize=24, fontweight='bold')

# Set the y-label formatting as whole numbers
plt.ticklabel_format(style='plain', axis='y')


sns.despine()

plt.xticks(fontsize=22)
plt.yticks(fontsize=22)


sns.despine()

plt.xticks(fontsize=24)
plt.yticks(fontsize=24)

plt.tight_layout()


# Show the plot
plt.show()

# %% [markdown]
# ## Income of Hyderabad

# %%
hyderabad_visitors_domestic_2019= 13802362
hyderabad_visitors_foreign_2019= 319300
hyderabad_visitors_domestic_2025=13703283
hyderabad_visitors_foreign_2025=317008

# %%
print('Hyderabad income in 2025 for Domestic Visitors {:.0f}'.format(hyderabad_visitors_domestic_2025*1200))
print('Hyderabad income in 2025 for Foreign Visitors {:.0f}'.format(hyderabad_visitors_foreign_2025*5600))
# Out:
# Hyderabad income in 2025 for Domestic Visitors 16443939600
# Hyderabad income in 2025 for Foreign Visitors 1775244800

# %% [markdown]
# ## Districts having the highest potential for tourism, also what steps should be taken

# %% [markdown]
# To identify the five districts with the highest potential for tourism growth based on the given data, we can consider the following factors:
#
# - Visitors: Look for districts with a higher number of visitors, indicating existing tourism activity.
# - Foreign Visitors: Consider districts with a higher number of foreign visitors, indicating international appeal and potential for attracting more international tourists.
# - df_ratio: Analyze the ratio of domestic visitors to foreign visitors, as a higher ratio suggests a greater focus on domestic tourism and potential for growth in international tourism.
# - Population: Consider the population of the district, as a larger population may indicate a larger potential market for tourism.
#
# Based on these factors, the top five districts with the highest potential for tourism growth are:
#
# - 1. Hyderabad
# - 2. Ranga Reddy
# - 3. Medchal
# - 4. Nizamabad
# - 5. Karimnagar
# These districts have a combination of high visitor numbers, a significant number of foreign visitors, a favorable df_ratio indicating potential for international tourism growth, and a large population to cater to.
#
# To leverage this data for tourism growth, the following steps can be taken:
#
# - Infrastructure Development: Invest in developing and improving tourism infrastructure such as accommodation facilities, transportation networks, and tourist attractions in these districts.
# - Marketing and Promotion: Implement targeted marketing campaigns to promote tourism in these districts, highlighting their unique attractions, cultural heritage, and natural beauty to both domestic and international tourists.
# - International Outreach: Strengthen efforts to attract more foreign visitors by collaborating with travel agencies, participating in international travel fairs, and promoting the districts' tourism offerings through various digital platforms.
# - Local Community Involvement: Involve local communities in tourism development initiatives, encouraging them to participate in tourism-related businesses and promoting cultural exchange and authentic experiences.
# - Skill Development: Provide training and skill development programs for the local population to enhance their capabilities in the tourism sector, ensuring high-quality services and experiences for visitors.
#
# These steps, coupled with effective planning, collaboration with stakeholders, and continuous monitoring and evaluation, can contribute to the sustainable growth of tourism in these districts and the overall region.

# %% [markdown]
# ### Based on the given data, the five districts with the highest potential for tourism growth are:
#
# #### 1. Hyderabad:
# Although it already has a high number of visitors, the foreign visitors ratio is low. Given its high population, if steps are taken to improve infrastructure and marketing, Hyderabad can attract more foreign tourists.
# #### 2. Adilabad:
# Adilabad has a high visitors to population ratio, indicating that there is potential for more tourism. The foreign visitors ratio is also relatively low, suggesting that steps can be taken to attract more foreign tourists.
# #### 3. Karimnagar:
# With a high number of visitors and a low foreign visitors ratio, Karimnagar has potential for growth in the tourism industry. Improving tourism infrastructure and promoting the district's unique attractions could help attract more tourists.
# #### 4. Mahbubnagar:
# Although it has a high number of visitors, the foreign visitors ratio is low. Promoting the district's unique attractions and improving infrastructure could help attract more tourists from outside the country.
# #### 5. Nagarkurnool:
# Although it has a low number of visitors, the visitors to population ratio is relatively high. Improving infrastructure and promoting the district's unique attractions could help attract more tourists.
#
# ###  To capitalize on the potential for tourism growth in these districts, the following steps can be taken:
#
# #### 1. Improve tourism infrastructure:
# This can include improving roads, airports, public transportation, and tourist accommodations. Better infrastructure can make it easier for tourists to visit and enjoy the district's attractions.
# #### 2. Promote unique attractions:
# Each district has unique attractions that can attract tourists. Promoting these attractions through marketing campaigns and local events can help increase the number of visitors.
# #### 3. Attract foreign tourists:
# To attract more foreign tourists, it may be necessary to develop language and cultural services, such as multilingual signage, language classes, and cultural events.
# #### 4. Provide training and support for local businesses:
# Local businesses can play a significant role in promoting tourism. Providing training and support for local businesses can help them develop and market products and services that are attractive to tourists.
# #### 5. Collaborate with neighboring districts:
# Collaborating with neighboring districts to develop tourism packages and promote each other's attractions can help attract more tourists to the region as a whole.
